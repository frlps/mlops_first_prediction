# %% [markdown]
# # Relatório de análise VII

# %% [markdown]
# ## Criando agrupamentos

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0  60.0     42.50   Apartamento
# 1   7000.0         0.0   0.0     70.00          Casa
# ...

# %%
dados.Valor.mean()
# Out:
# 5046.172821405663

# %% [markdown]
# ## https://pandas.pydata.org/pandas-docs/stable/reference/frame.html

# %%
dados['Bairro'].unique()
# Out:
# array(['Copacabana', 'Jardim Botânico', 'Centro', 'Higienópolis',
#        'Cachambi', 'Barra da Tijuca', 'Ramos', 'Grajaú',
#        'Lins de Vasconcelos', 'Taquara', 'Freguesia (Jacarepaguá)',
#        'Tijuca', 'Olaria', 'Ipanema', 'Campo Grande', 'Botafogo',
#        'Recreio dos Bandeirantes', 'Leblon', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'São Conrado', 'Vila Valqueire', 'Gávea', 'Cosme Velho',
#        'Bonsucesso', 'Todos os Santos', 'Laranjeiras', 'Itanhangá',
#        'Flamengo', 'Piedade', 'Lagoa', 'Catete', 'Jardim Carioca',
#        'Benfica', 'Glória', 'Praça Seca', 'Vila Isabel', 'Engenho Novo',
#        'Engenho de Dentro', 'Pilares', 'Água Santa', 'São Cristóvão',
#        'Ilha do Governador', 'Jardim Sulacap', 'Oswaldo Cruz',
#        'Vila da Penha', 'Anil', 'Vargem Grande', 'Tanque', 'Vaz Lobo',
#        'Madureira', 'São Francisco Xavier', 'Pechincha', 'Leme', 'Irajá',
# ...

# %%
dados['Bairro'].value_counts()
# Out:
# Barra da Tijuca             3863
# Copacabana                  2644
# Ipanema                     1764
# Recreio dos Bandeirantes    1649
# Leblon                      1258
#                             ...
# Cachamorra                     1
# Coelho Neto                    1
# Caju                           1
# Rio da Prata                   1
# Cidade Jardim                  1
# Name: Bairro, Length: 152, dtype: int64

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = dados['Bairro'].isin(bairros)
dados = dados[selecao]

# %%
dados.head(30)
# Out:
#                   Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete       Copacabana        1      0       0    40
# 5   Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 9          Apartamento       Copacabana        1      0       1    40
# 10           Quitinete       Copacabana        1      0       0    27
# 11         Apartamento       Copacabana        4      3       1   243
# 14         Apartamento  Barra da Tijuca        2      1       1    67
# 15         Apartamento           Tijuca        2      1       0   110
# 16  Casa de Condomínio  Barra da Tijuca        4      3       2   466
# 18         Apartamento           Tijuca        2      1       0    78
# 19         Apartamento          Ipanema        3      1       1   125
# 20         Apartamento           Tijuca        1      0       0    48
# 21         Apartamento  Barra da Tijuca        3      3       1   175
# ...

# %%
dados['Bairro'].unique()
# Out:
# array(['Copacabana', 'Barra da Tijuca', 'Tijuca', 'Ipanema', 'Botafogo',
#        'Leblon', 'Flamengo'], dtype=object)

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0          Copacabana
# 5     Barra da Tijuca
# 15             Tijuca
# 19            Ipanema
# 23           Botafogo
# 27             Leblon
# 78           Flamengo
# Name: Bairro, dtype: object

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': [5, 14, 16, 21, 30, 32, 35, 42, 43, 60, 61, 64, 68, 74, 79, 93, 107, 110, 112, 117, 130, 132, 136, 150, 153, 155, 165, 166, 173, 186, 189, 207, 214, 221, 224, 233, 236, 239, 244, 259, 265, 274, 276, 291, 292, 293, 295, 302, 308, 311, 325, 335, 336, 345, 360, 366, 368, 374, 380, 387, 389, 400, 412, 432, 433, 435, 436, 439, 449, 451, 462, 463, 465, 473, 476, 484, 494, 500, 503, 511, 537, 538, 539, 540, 543, 547, 552, 554, 555, 556, 584, 587, 588, 590, 594, 596, 601, 611, 622, 630, ...], 'Botafogo': [23, 48, 87, 88, 111, 119, 127, 134, 196, 200, 225, 334, 362, 415, 416, 498, 524, 526, 545, 593, 649, 685, 719, 756, 765, 822, 827, 861, 915, 924, 928, 1006, 1043, 1080, 1091, 1110, 1116, 1127, 1140, 1165, 1201, 1205, 1223, 1250, 1282, 1295, 1304, 1317, 1348, 1383, 1414, 1419, 1455, 1517, 1529, 1579, 1630, 1655, 1670, 1699, 1741, 1742, 1788, 1814, 1823, 1826, 1853, 1922, 1931, 1957, 1972, 1981, 1989, 2029, 2066, 2069, 2081, 2083, 2084, 2088, 2097, 2148, 2149, 2165, 2179, 
# ...

# %%
for bairro, dados in grupo_bairro:
    print(bairro)
# Out:
# Barra da Tijuca
# Botafogo
# Copacabana
# Flamengo
# Ipanema
# Leblon
# Tijuca

# %%
for bairro, dados in grupo_bairro:
    print(dados)
# Out:
#                      Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 5      Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 14            Apartamento  Barra da Tijuca        2      1       1    67
# 16     Casa de Condomínio  Barra da Tijuca        4      3       2   466
# 21            Apartamento  Barra da Tijuca        3      3       1   175
# 30            Apartamento  Barra da Tijuca        3      1       2    70
# ...                   ...              ...      ...    ...     ...   ...
# 21801  Casa de Condomínio  Barra da Tijuca        3      5       3  1000
# 21811         Apartamento  Barra da Tijuca        2      1       1    85
# 21812         Apartamento  Barra da Tijuca        3      2       0    98
# 21813         Apartamento  Barra da Tijuca        3      2       2   140
# 21820  Casa de Condomínio  Barra da Tijuca        5      3       4   450
#
#          Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# ...

# %%
for bairro, data in grupo_bairro:
    print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
for bairro, data in grupo_bairro:
    print('{} -> {}'.format (bairro, data['Valor'].mean()))
# Out:
# Barra da Tijuca -> 7069.552938130986
# Botafogo -> 8791.828178694159
# Copacabana -> 4126.677004538578
# Flamengo -> 4113.526610644258
# Ipanema -> 9352.001133786847
# Leblon -> 8746.344992050874
# Tijuca -> 2043.52

# %%
grupo_bairro['Valor'].mean().round(2)
# Out:
# Bairro
# Barra da Tijuca    7069.55
# Botafogo           8791.83
# Copacabana         4126.68
# Flamengo           4113.53
# Ipanema            9352.00
# Leblon             8746.34
# Tijuca             2043.52
# Name: Valor, dtype: float64

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                    Valor  Condominio
# Bairro
# Barra da Tijuca  7069.55     3591.01
# Botafogo         8791.83      976.28
# Copacabana       4126.68     1148.68
# Flamengo         4113.53     1102.15
# Ipanema          9352.00     2244.44
# Leblon           8746.34     2107.18
# Tijuca           2043.52      711.69

# %%
grupo_bairro['Valor'].mean().round(2)
# Out:
# Bairro
# Barra da Tijuca    7069.55
# Botafogo           8791.83
# Copacabana         4126.68
# Flamengo           4113.53
# Ipanema            9352.00
# Leblon             8746.34
# Tijuca             2043.52
# Name: Valor, dtype: float64

# %% [markdown]
# # 8.3 Exercício: Sumarizando informações

# %%
alunos_1 = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]})

# %%
alunos_1
# Out:
#      Nome Sexo  Idade  Notas  Aprovado
# 0     Ary    M     15    7.5      True
# 1   Cátia    F     27    2.5     False
# 2   Denis    M     56    5.0     False
# 3    Beto    M     32   10.0      True
# 4   Bruna    F     42    8.2      True
# 5    Dara    F     21    7.0      True
# 6  Carlos    M     19    6.0     False
# 7   Alice    F     35    5.6     False

# %%
sexo = alunos.groupby('Sexo')
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %% [markdown]
# # Estatísticas descritivas

# %%
grupo_bairro.describe()
# Out:
#                 Quartos                                                 Vagas  \
#                   count      mean       std  min  25%  50%  75%   max   count
# Bairro
# Barra da Tijuca  3863.0  3.054362  1.203803  0.0  2.0  3.0  4.0  14.0  3863.0
# Botafogo          873.0  2.163803  1.062052  0.0  1.0  2.0  3.0  12.0   873.0
# Copacabana       2644.0  2.281014  1.112344  0.0  1.0  2.0  3.0   6.0  2644.0
# Flamengo          714.0  2.212885  1.144314  0.0  1.0  2.0  3.0   6.0   714.0
# Ipanema          1764.0  2.771542  0.951141  0.0  2.0  3.0  3.0  10.0  1764.0
# Leblon           1258.0  2.835453  0.961858  0.0  2.0  3.0  4.0   6.0  1258.0
# Tijuca           1100.0  2.331818  0.840234  0.0  2.0  2.0  3.0  10.0  1100.0
#
#                            ...    IPTU           Valor m2             \
#                      mean  ...     75%       max    count       mean
# Bairro                     ...
# Barra da Tijuca  2.148330  ...  807.00  450625.0   3863.0  35.732185
# ...

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                   count     mean        std     min     25%     50%      75%  \
# Bairro
# Barra da Tijuca  3863.0  7069.55   11874.15   800.0  2500.0  4500.0   8500.0
# Botafogo          873.0  8791.83  152202.41   700.0  2200.0  3000.0   4350.0
# Copacabana       2644.0  4126.68    3611.41   100.0  2000.0  3000.0   4800.0
# Flamengo          714.0  4113.53    3839.13   800.0  1900.0  2900.0   4975.0
# Ipanema          1764.0  9352.00    8219.72  1200.0  4500.0  7000.0  11000.0
# Leblon           1258.0  8746.34    7004.04   100.0  4500.0  7000.0  10500.0
# Tijuca           1100.0  2043.52    1664.34   750.0  1500.0  1800.0   2300.0
#
#                        max
# Bairro
# Barra da Tijuca   600000.0
# Botafogo         4500000.0
# Copacabana         35000.0
# Flamengo           35000.0
# Ipanema            90000.0
# Leblon            100000.0
# Tijuca             45000.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum'])
# Out:
#                     min        max         sum
# Bairro
# Barra da Tijuca   800.0   600000.0  27309683.0
# Botafogo          700.0  4500000.0   7675266.0
# Copacabana        100.0    35000.0  10910934.0
# Flamengo          800.0    35000.0   2937058.0
# Ipanema          1200.0    90000.0  16496930.0
# Leblon            100.0   100000.0  11002902.0
# Tijuca            750.0    45000.0   2247872.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max']).rename(columns = {'min': 'Mínimo', 'max': 'Máximo'})
# Out:
#                  Mínimo     Máximo
# Bairro
# Barra da Tijuca   800.0   600000.0
# Botafogo          700.0  4500000.0
# Copacabana        100.0    35000.0
# Flamengo          800.0    35000.0
# Ipanema          1200.0    90000.0
# Leblon            100.0   100000.0
# Tijuca            750.0    45000.0

# %% [markdown]
# ## https://matplotlib.org/

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (30,15))

# %%
fig = grupo_bairro['Valor'].std().plot.bar(color = 'blue')

# %%
fig = grupo_bairro['Valor'].mean().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
fig = grupo_bairro['Valor'].max().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize': 22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %% [markdown]
# # Exercício 8.5 Selecionando as estatísticas descritivas

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto')
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0
